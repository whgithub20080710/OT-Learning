# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,2,3,4,5,6,7,8])
y = np.array([3,5,6,2,9,4,7,4])
plt.plot(x,y,'r')# 折线 x,y,color
#plt.plot(x,y,'g',lw=10)#lw:线宽
x = np.array([1,2,3,4,5,6,7,8])
y = np.array([13,15,16,12,19,14,17,14])
plt.bar(x,y,0.2,alpha=1,color='b')# 5 color 4 透明度 3 宽度
plt.show()
